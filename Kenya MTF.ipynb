# %%
import pandas as pd
import numpy as np
import plotly as plt
import datascience
from datascience import *

# %%
chunksize = 10

#appending chunks to chatbot_list, an empty array
mtf_list = []
chunksize = 10
for chunk in pd.read_csv("kenya_mtf2_joined.csv", encoding='latin-1', chunksize = chunksize):
    mtf_list.append(chunk)

#Combine all the chunks into one dataframe
kenya_mtf2 = pd.concat(mtf_list, axis=0)
kenya_mtf2 = pd.DataFrame(data = kenya_mtf2)

# %%
kenya_mtf2
# Out:
#                                      parent_key elc_aggr_tier    cluuq  \
# 0     uuid:0006ae15-e9cf-419e-ac14-0c66a739366e        Tier 0  2841_15
# 1     uuid:001b24c5-30b9-41fe-ac90-9e9e3e476935        Tier 5    756_4
# 2     uuid:0031732a-2efc-43e7-ba34-9447ddc31b32        Tier 2   4594_3
# 3     uuid:0042ae86-e063-4b44-a859-9c253d82bd38        Tier 0   6380_2
# 4     uuid:006014f9-c69e-48b2-8198-60cbbc894b59        Tier 0   4276_7
# ...                                         ...           ...      ...
# 4544  uuid:ffc9befd-9639-4be7-87d4-6e2f23b08b8a        Tier 0   1001_3
# 4545  uuid:ffcdc11f-b943-451b-af2d-de205a92c090        Tier 0   6619_4
# 4546  uuid:ffd5c40a-c387-41fd-84fe-4a259ebccd5d        Tier 0    965_7
# 4547  uuid:ffe36929-1f6b-4a17-bbd6-d7c4aec6abaf        Tier 1   2816_3
# 4548  uuid:ffef3fc2-114d-46f8-8811-941c54ee9eb0        Tier 4    142_1
#
#             hh_code           prov          cty              dist  \
# ...

# %%
kenya_mtf2 = Table.from_df(kenya_mtf2, keep_index =False)
kenya_mtf2
# Out:
# parent_key                                | elc_aggr_tier | cluuq   | hh_code       | prov          | cty          | dist             | div        | loc       | subloc   | class | locality_ur | marg                | grid_loc                  | subdate    | locality | enum_id | enum_foot | enum_ht | sup_id | tab_id | start_time     | a_a_1 | q_options | b_b_1 | b_b_2 | b_b_3 | b_b_4 | b_b_5                                                      | b_b_6a | b_b_7 | b_b_8  | b_b_9 | b_b_10                        | b_b_11                | b_b12                | b_b_13a               | b_b_13b | b_b_13c | b_b_14              | b_b_15 | b_b_16 | b_b_17                   | b_b_18 | b_b_19a            | b_b_19b | b_b_20a                  | b_b_20b         | b_b_20c | b_b_20d | b_b_20e | b_b_21 | b_b_22 | b_b_23 | b_b_24a                                   | b_b_24b                                | b_b_24c                                   | b_b_24d                    | b_b_24e                   
# ...
