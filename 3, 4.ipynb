# %%
# Import packages

import pandas as pd
import numpy as np

# %%
import altair as alt

# %%
# Load Kenya MTF Data 

chunksize = 10

mtf_list = []
chunksize = 10
for chunk in pd.read_csv("section_l.csv", encoding='latin-1', chunksize = chunksize):
    mtf_list.append(chunk)
    
section_l = pd.concat(mtf_list, axis=0)
df = pd.DataFrame(data = section_l)

# %%
# Tools

import functools
def conjunction(*conditions):
    return functools.reduce(np.logical_and, conditions)

# %%
def catalyst(*args, **kwargs):
    font = "Times New Roman"
    labelFont = "Times New Roman" 
    sourceFont = "Times New Roman"
    # Axes
    axisColor = "#000000"
    gridColor = "#DEDDDD"
    # Colors
    main_palette = [   '#2980B9', #(light blue)
        '#003366', #(dark blue)
        '#FFAE19', #(gold)
        '#D68910', #(dark gold)
        '#E67E22', #(orange)
        '#D35400', #(dark orange)
        '#FF4500', #(red)
        '#FF6162', #(dark pink/red)
        '#438B28', #(green)
        '#45B39D', #(teal)
        '#99ADC1', #(light gray)
        '#212F3C', #(dark gray)
    ]
    return {
        "width": 800, 
        "height": 400, 
        "config": {
            "title": {
                "fontSize": 18,
                "font": font,
                "anchor": "center",
                "fontColor": "#000000",
            },
            "axisX": {
                "domain": True,
                "domainColor": axisColor,
                #"domainWidth": 1,
                "grid": False,
                "labelFont": labelFont,
                "labelFontSize": 14,
                #"labelAngle": 0,
                #"tickColor": axisColor,
                #"tickSize": 5, 
                "titleFont": font,
                "titleFontSize": 14,
                "titleFontWeight": "normal",
                #"titlePadding": 10, 
                "title": "X Axis Title (units)", 
                #"titleAngle":0
            },
            "axisY": {
                "domain": True,
                "grid": False,
                "gridColor": gridColor,
                "gridWidth": 1,
                "labelFont": labelFont,
                "labelFontSize": 14,
                "labelAngle": 0,
                "ticks": False, 
                "titleFont": font,
                "titleFontSize": 14,
                "titleFontWeight": "normal",
                "titlePadding": 10, 
                "title": "Y Axis Title (units)",
                #"titleY": -10, 
                #"titleX": 18,
                #"titleAngle": 0 #-90
            },
            "range": {
                "category": main_palette
            },
            "legend": {
                "labelFont": labelFont,
                "labelFontSize": 14,
                "symbolType": "square", 
                "symbolSize": 100, 
                "titleFont": font,
                "titleFontSize": 14,
                "titleFontWeight": "normal",
                "title": "Legend", 
                "orient": "right", 
                "offset": 0, 
            },
            "tooltip":{
                "font": "Open Sans"
            },
            "view": {
                "stroke": "transparent", 
        ### MARKS CONFIGURATIONS ###
           "text": {
               "font": "Times New Roman",
               "color": main_palette,
               "fontSize": 14,
               "align": "right",
               "fontWeight": 400,
               "size": 14,
           }, 
           "bar": {
                "size": 40,
                "binSpacing": 1,
                "continuousBandSize": 30,
                "discreteBandSize": 30,
                "fill": main_palette,
                "stroke": False,
           },
            }
        }
    }

# %%
alt.themes.register('catalyst', catalyst)
alt.themes.enable('catalyst');

# %%
# Load Kenya MTF Data 

chunksize = 10

mtf_list = []
chunksize = 10
for chunk in pd.read_csv("module3.csv", encoding='latin-1', chunksize = chunksize):
    mtf_list.append(chunk)
    
module3 = pd.concat(mtf_list, axis=0)
module3 = pd.DataFrame(data = module3)

# %%
# Primary cooking fuel

cooking_options = [None, 'Firewood', 'Charcoal', 'LPG/cooking gas', 'Kerosene', 
                    'Biomass Briquette', 'Electricity', 'Biogas', 
                    'Coal/lignite']

cooking_labels = ['All responses', 'Firewood', 'Charcoal', 'LPG/cooking gas', 'Kerosene',
                    'Biomass Briquette', 'Electricity', 'Biogas', 
                    'Coal/lignite']

cooking_dropdown = alt.binding_select(
    options = cooking_options, 
    labels = cooking_labels, 
    name = "Primary source of cooking fuel  ")

cooking_select=alt.selection_single(
    fields=['Primary_1st_fuel'],
    bind=cooking_dropdown)

# Primary cookstove filter

cookstove_options = [None, 'Three stone/Open fire',
                'Manufactured stove',
                'Other Self-Built Stove',
                'Other']

cookstove_labels = ['All responses', 'Three stone/Open fire',
                'Manufactured stove',
                'Other Self-Built Stove',
                'Other']

cookstove_dropdown = alt.binding_select(
    options = cookstove_options, 
    labels = cookstove_labels, 
    name = "Primary cookstove  ")

cookstove_select=alt.selection_single(
    fields=['Primary_stove_type'],
    bind=cookstove_dropdown)

# Primary lighting filter 

lighting_options = [None, 'National grid',
                   'Rechargeable Battery',
                   'No electricity', 
                   'Solar Lantern/Lighting System',
                   'Solar Home System',
                   'Generator (Connecting one or more households)',
                   'Other']

lighting_labels = ['All responses', 'National grid',
                   'Rechargeable Battery',
                   'No electricity', 
                   'Solar Lantern/Lighting System',
                   'Solar Home System',
                   'Generator',
                   'Other']

lighting_dropdown = alt.binding_select(
    options = lighting_options, 
    labels = lighting_labels, 
    name = "Primary source of electricity  ")

lighting_select=alt.selection_single(
    fields=['c_c_156'],
    bind=lighting_dropdown)

# %%
# Tools

import functools
def conjunction(*conditions):
    return functools.reduce(np.logical_and, conditions)

# %%
df
# Out:
#      elc_aggr_tier  c_c_160 locality_ur c_c_156 Primary_1st_fuel  \
# 1           Tier 5      1.0       Urban     NaN  LPG/cooking gas
# 2           Tier 2      2.0       Rural     NaN         Firewood
# 3           Tier 0      2.0       Rural     NaN         Firewood
# 4           Tier 0      0.0       Rural     NaN              NaN
# 5           Tier 3      3.0       Rural     NaN         Charcoal
# ...            ...      ...         ...     ...              ...
# 4541        Tier 0      1.0       Rural     NaN         Firewood
# 4542        Tier 5      2.0       Rural     NaN         Charcoal
# 4543        Tier 3      3.0       Urban     NaN         Charcoal
# 4547        Tier 1      2.0       Rural     NaN         Firewood
# 4548        Tier 4      2.0       Rural     NaN              NaN
#
#           Primary_stove_type
# 1         Manufactured stove
# 2      Three stone/Open fire
# 3     Other Self-Built Stove
# 4                        NaN
# 5      Three stone/Open fire
# ...                      ...
# 4541   Three stone/Open fire
# 4542      Manufactured stove
# 4543      Manufactured stove
# 4547   Three stone/Open fire
# 4548                     NaN
#
# [3439 rows x 6 columns]

# %%
# How many mobile phones do the household members own combined?

alt.data_transformers.disable_max_rows()
source = module3[module3[['c_c_160', 'c_c_156', 'locality_ur', 'elc_aggr_tier', 'Primary_1st_fuel', 'Primary_stove_type']].notnull().all(1)]

c_1 = source['c_c_160'] != 'NaN'
c_2 = source['elc_aggr_tier'] != 'NaN'
c_3 = source['c_c_156'] != 'NaN'
c_4 = source['Primary_1st_fuel'] != 'NaN'
c_5 = source['Primary_stove_type'] != 'NaN'
c_6 = source['locality_ur'] != 'NaN'

source = source[conjunction(c_1,c_2, c_3, c_4, c_5, c_6)]
#df = source[['elc_aggr_tier','c_c_160', 'locality_ur', 'c_c_156', 'Primary_1st_fuel','Primary_stove_type']]

df = source[['elc_aggr_tier', 'locality_ur', 'Primary_1st_fuel', 'Primary_stove_type', 'c_c_156', 'c_c_160']]

###########

# Primary cooking fuel

cooking_options = [None, 'Firewood', 'Charcoal', 'LPG/cooking gas', 'Kerosene', 
                    'Biomass Briquette', 'Electricity', 'Biogas', 
                    'Coal/lignite']

cooking_labels = ['All responses', 'Firewood', 'Charcoal', 'LPG/cooking gas', 'Kerosene',
                    'Biomass Briquette', 'Electricity', 'Biogas', 
                    'Coal/lignite']

cooking_dropdown = alt.binding_select(
    options = cooking_options, 
    labels = cooking_labels, 
    name = "Primary source of cooking fuel  ")

cooking_select=alt.selection_single(
    fields=['Primary_1st_fuel'],
    bind=cooking_dropdown)

# Primary cookstove filter

cookstove_options = [None, 'Three stone/Open fire',
                'Manufactured stove',
                'Other Self-Built Stove',
                'Other']

cookstove_labels = ['All responses', 'Three stone/Open fire',
                'Manufactured stove',
                'Other Self-Built Stove',
                'Other']

cookstove_dropdown = alt.binding_select(
    options = cookstove_options, 
    labels = cookstove_labels, 
    name = "Primary cookstove  ")

cookstove_select=alt.selection_single(
    fields=['Primary_stove_type'],
    bind=cookstove_dropdown)

# Primary lighting filter 

lighting_options = [None, 'National grid',
                   'Rechargeable Battery',
                   'No electricity', 
                   'Solar Lantern/Lighting System',
                   'Solar Home System',
                   'Generator (Connecting one or more households)',
                   'Other']

lighting_labels = ['All responses', 'National grid',
                   'Rechargeable Battery',
                   'No electricity', 
                   'Solar Lantern/Lighting System',
                   'Solar Home System',
                   'Generator',
                   'Other']

lighting_dropdown = alt.binding_select(
    options = lighting_options, 
    labels = lighting_labels, 
    name = "Primary source of electricity  ")

lighting_select=alt.selection_single(
    fields=['c_c_156'],
    bind=lighting_dropdown)

#############

c160 = alt.Chart(df).transform_joinaggregate(
    total='count(*)'
).transform_calculate(
    pct='1 / datum.total'                
).mark_bar(color = '#2980B9'
).encode(
    alt.X("c_c_160", 
          bin=alt.Bin(extent=[0, 10], step=1), 
          scale = alt.Scale(domain=(0,10),clamp = True),
         axis = alt.Axis(title = " ")),
    y= alt.Y('sum(pct):Q', axis=alt.Axis(format='%'), title = " "),
    tooltip = [alt.Tooltip('c_c_160:N', title = "Response (Binned)"), 
               alt.Tooltip('sum(pct):Q', format = '.2%', title = "Percentage")]
).transform_bin(
    "mbin",
    field="m",
    bin=alt.Bin(maxbins=20)
).properties(
    height = 500,
    width = 800
)

chart = c160.properties(
    title={
      "text": ["How many mobile phones do the household members own combined?"],
      "color": "black",
        "font": 'Times New Roman'
    }
)

final = alt.concat(chart,
    title=alt.TitleParams(
        ['', '',  
         'This chart includes responses from 74.92% of households in the Kenya MTF survey sample (total size = 4,590).',
         'Use the dropdown filters to interact with the data.'],
        baseline='bottom',
        orient='bottom',
        anchor='start',
        font = 'Times New Roman',
        fontWeight='normal',
        fontStyle = "italic",
        fontSize=15)
).add_selection(
    tier_select
).transform_filter(
    tier_select 
).add_selection( # Sixth, cookstove filter
    cookstove_select
).transform_filter(
    cookstove_select
).add_selection( # Fifth, cooking fuel filter
    cooking_select
).transform_filter(
    cooking_select
).add_selection( # Fourth, primary source of lighting
    lighting_select
).transform_filter(
    lighting_select  
).add_selection( # First, locality filter
    locality_select
).transform_filter(
    locality_select
)

final = final.configure(font = 'Times New Roman')
final
# Out:
# alt.ConcatChart(...)

# %%
df.shape[0] / 4590
# Out:
# 0.7492374727668846

# %%
final.save('Number of Phones the Household Owns.html')

# %%
final.save('Number of Phones the Household Owns.json')

# %%
# Module 4

# %%
# Load Kenya MTF Data 

chunksize = 10

mtf_list = []
chunksize = 10
for chunk in pd.read_csv("module4.csv", encoding='latin-1', chunksize = chunksize):
    mtf_list.append(chunk)
    
module4 = pd.concat(mtf_list, axis=0)
module4 = pd.DataFrame(data = module4)

# %%
# How many years have you lived in this community?
alt.data_transformers.disable_max_rows()
source1 = module4[module4[['b_b_9']].notnull().all(1)]

c_1 = source1['b_b_9'] != 'NaN'
c_2 = source1['elc_aggr_tier'] != 'NaN'

source = source1[conjunction(c_1,c_2)]
df = source[['elc_aggr_tier','b_b_9', 'locality_ur']]

tiers = [None, 'Tier 0', 'Tier 1', 'Tier 2', 'Tier 3', 'Tier 4', 'Tier 5']
tier_labels = ['All Tiers', 'Tier 0', 'Tier 1', 'Tier 2', 'Tier 3', 'Tier 4', 'Tier 5']
tier_dropdown=alt.binding_select(options=tiers, 
                                 labels = tier_labels, 
                                 name = "Electricity Tier  ")
tier_select=alt.selection_single(fields=['elc_aggr_tier'],
                                bind=tier_dropdown)

chart = alt.Chart(df).transform_joinaggregate(
    total='count(*)'
).transform_calculate(
    pct='1 / datum.total'
).mark_bar(color = '#2980B9'
).encode(
    alt.X("b_b_9:Q", 
          bin=alt.Bin(extent=[1, 15], step=1), 
          scale = alt.Scale(domain=(1,15),clamp = True),
         axis = alt.Axis(title = " ")),
    alt.Y('sum(pct):Q', axis=alt.Axis(format='%'), title = " "),
    tooltip = [alt.Tooltip('b_b_9:N', title = "Response (Binned)"), 
               alt.Tooltip('sum(pct):Q', format = '.2%', title = "Percentage")]
).transform_bin(
    "mbin",
    field="m",
    bin=alt.Bin(maxbins=20)
).add_selection(
    locality_select
).transform_filter(
    locality_select
).add_selection(
    tier_select
).transform_filter(
    tier_select 
).properties(
    height = 500,
    width = 800
)

chart = chart.properties(
    title={
      "text": ["Number of Rooms the Household Occupies"],
      "color": "black",
        "font": 'Times New Roman'
    }
)

final = alt.concat(chart,
    title=alt.TitleParams(
        ['', '',  
         'This chart includes responses from 94.53% of households in the Kenya MTF survey sample (total size = 4,590).',
         'Use the dropdown filters to interact with the data.'],
        baseline='bottom',
        orient='bottom',
        anchor='start',
        font = 'Times New Roman',
        fontWeight='normal',
        fontStyle = "italic",
        fontSize=15)
)

final = final.configure(font = 'Times New Roman')
final
# Out:
# alt.ConcatChart(...)

# %%
final.save('Number of Rooms the Household Occupies.html')

# %%
final.save('Number of Rooms the Household Occupies.json')

# %%
df.shape[0]/4590
# Out:
# 0.9453159041394336

# %%
alt.data_transformers.disable_max_rows()
source1 = module4[module4[['b_b_10']].notnull().all(1)]

c_1 = source1['b_b_10'] != 'NaN'
c_2 = source1['elc_aggr_tier'] != 'NaN'

source = source1[conjunction(c_1,c_2)]
df = source[['elc_aggr_tier','b_b_10', 'locality_ur']]

base = alt.Chart(df).transform_joinaggregate(
    total = 'count(*)'
).transform_calculate(
    pct = '1 / datum.total'
).encode(
    x = alt.X('b_b_10:N', 
              sort=alt.EncodingSortField(field="b_b_10", op="count", order='descending'),
              axis = alt.Axis(title = ' ')),
    y = alt.Y('sum(pct):Q', axis = alt.Axis(title = "", format = '%')),
    #color = alt.Color('b_b_10', legend=None),
    tooltip = alt.Tooltip('b_b_10')
).properties(
    height = 500,
    width = 800)
     
locality_options = [None, 'Urban', 'Rural']
locality_labels = ['National', 'Urban', 'Rural']

locality_dropdown=alt.binding_select(
    options= locality_options, 
    labels = locality_labels, 
    name = "Locality Breakdown  ")
locality_select=alt.selection_single(
    fields=['locality_ur'],
    bind=locality_dropdown)

tiers = [None, 'Tier 0', 'Tier 1', 'Tier 2', 'Tier 3', 'Tier 4', 'Tier 5']
tier_labels = ['All Tiers', 'Tier 0', 'Tier 1', 'Tier 2', 'Tier 3', 'Tier 4', 'Tier 5']
tier_dropdown=alt.binding_select(options=tiers, 
                                 labels = tier_labels, 
                                 name = "Electricity Tier  ")
tier_select=alt.selection_single(fields=['elc_aggr_tier'],
                                bind=tier_dropdown)

chart = (base.mark_bar(size = 40,color= '#2980B9') + base.mark_text(
    align = 'center', baseline='bottom', size = 13.5
).encode(
    text = alt.Text('sum(pct):Q', format = '.2%'))
).add_selection(
    locality_select
).transform_filter(
    locality_select
).add_selection(
    tier_select
).transform_filter(
    tier_select 
).properties(
    height = 500,
    width = 800
)

chart = chart.properties(
    title={
      "text": ["What are the walls of the dwelling made of?"],
      "color": "black",
        "font": 'Times New Roman'
    }
)

final = alt.concat(chart,
    title=alt.TitleParams(
        ['', '',  
         'This chart includes responses from 97.91% of households in the Kenya MTF survey sample (total size = 4,590).',
         'Use the dropdown filters to interact with the data.'],
        baseline='bottom',
        orient='bottom',
        anchor='start',
        font = 'Times New Roman',
        fontWeight='normal',
        fontStyle = "italic",
        fontSize=15)
)

final = final.configure(font = 'Times New Roman')
final
# Out:
# alt.ConcatChart(...)

# %%
df.shape[0] / 4590
# Out:
# 0.9790849673202614

# %%
final.save('Wall Dwelling Materials.html')

# %%
final.save('Wall Dwelling Materials.json')

# %%
# data
alt.data_transformers.disable_max_rows()
source1 = module4[module4[['b_b_10', 'b_b_11', 'b_b12']].notnull().all(1)]

c_1 = source1['b_b_10'] != 'NaN'
c_2 = source1['elc_aggr_tier'] != 'NaN'

source = source1[conjunction(c_1,c_2)]
df = source[['elc_aggr_tier','b_b_10', 'b_b_11', 'b_b12', 'locality_ur']]
df
# Configure common options
base = alt.Chart(df).transform_aggregate(
    cookstove_count='count()',
    groupby=['b_b_10', 'b_b12']
).encode(
    alt.Y('b_b_10:O', scale=alt.Scale(paddingInner=0), title = "Wall Material"),
    alt.X('b_b12:O', scale=alt.Scale(paddingInner=0), title = "Floor Material"),
)

# Configure heatmap
heatmap = base.mark_rect().encode(
    color=alt.Color('cookstove_count:Q',
        scale=alt.Scale(scheme='blues'),
        legend=None
    )
)

# Configure text
text = base.mark_text(baseline='middle', size = 15
).transform_joinaggregate(
    count = 'count(cookstove_count)',
    groupby = ['b_b_10', 'b_b12']
).transform_calculate(
    pct = alt.datum.cookstove_count / df.shape[0]
).encode(
    text=alt.Text('pct:Q', format = '.2%'),
    color=alt.condition(
        alt.datum.cookstove_count < 100,
        alt.value('black'),
        alt.value('white')
    )
)

locality_options = [None, 'Urban', 'Rural']
locality_labels = ['National', 'Urban', 'Rural']

locality_dropdown=alt.binding_select(
    options= locality_options, 
    labels = locality_labels, 
    name = "Locality Breakdown  ")
locality_select=alt.selection_single(
    fields=['locality_ur'],
    bind=locality_dropdown)

tiers = [None, 'Tier 0', 'Tier 1', 'Tier 2', 'Tier 3', 'Tier 4', 'Tier 5']
tier_labels = ['All Tiers', 'Tier 0', 'Tier 1', 'Tier 2', 'Tier 3', 'Tier 4', 'Tier 5']
tier_dropdown=alt.binding_select(options=tiers, labels = tier_labels, name = "Electricity Tier  ")
tier_select=alt.selection_single(fields=['elc_aggr_tier'],
                                bind=tier_dropdown)

roofs = [None, 'Corrugated iron sheet', 'Concrete/Cement', 'Thatch', 'Wood and mud', 'Bamboo/Reed', 
         'Plastic canvas', 'Asbestos', 'Bricks']
roof_labels = ['All Roof types', 'Corrugated iron sheet', 'Concrete/Cement', 'Thatch', 'Wood and mud', 'Bamboo/Reed', 
         'Plastic canvas', 'Asbestos', 'Bricks']
roof_dropdown=alt.binding_select(options=roofs, labels = roof_labels, name = "Roof Material ")
roof_select=alt.selection_single(fields=['b_b_11'],
                                bind=roof_dropdown)

# Draw the chart
chart = (heatmap + text).properties(
    height = 500,
    width = 800
).add_selection(
    locality_select
).transform_filter(
    locality_select
).add_selection(
    tier_select
).transform_filter(
    tier_select 
).add_selection(
    roof_select
).transform_filter(
    roof_select
)

chart = chart.properties(
    title={
      "text": ["Floor vs. Wall Dwelling Material"],
      "color": "black",
        "font": 'Times New Roman'
    }
)

final = alt.concat(chart,
    title=alt.TitleParams(
        ['', '',  
         'This chart includes responses from 97.91% of households in the Kenya MTF survey sample (total size = 4,590).',
         'Use the dropdown filters to interact with the data.'],
        baseline='bottom',
        orient='bottom',
        anchor='start',
        font = 'Times New Roman',
        fontWeight='normal',
        fontStyle = "italic",
        fontSize=15)
)

final = final.configure(font = 'Times New Roman').configure_title(
    fontSize=20, offset=5, orient='top', anchor='middle'
)

final
# Out:
# alt.ConcatChart(...)

# %%
final.save('Floor vs. Wall Dwelling Material.html')

# %%
final.save('Floor vs. Wall Dwelling Material.json')
